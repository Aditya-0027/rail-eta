# %% [markdown]
# # RailETA — free ML training notebook
# This notebook trains a historical delay-risk model from the Kaggle `ir_train.csv`. The dataset is synthetic/educational, so label the result accordingly in your demo.

# %%
# !pip -q install pandas scikit-learn joblib

# %% [markdown]
# ## 1. Get `ir_train.csv`
# Download `ir_train.csv` from the Kaggle competition page after accepting its rules, then upload it to Colab.

# %%
from google.colab import files
uploaded = files.upload()

# %%
# !python ml/train_model.py --csv ir_train.csv --sample 300000

# %% [markdown]
# The resulting `model/eta_delay_model.joblib` can be copied into the RailETA deployment. Render performs inference only; training stays on Colab/laptop.
